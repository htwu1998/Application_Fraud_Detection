# %%
# Load libraries
import datetime as dt
from datetime import datetime
import time 
import calendar
start_time = datetime.now()

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import scipy.stats as sps
import random

print('LOAD DURATION:',datetime.now() - start_time)
# Out:
# LOAD DURATION: 0:00:01.273163

# %%
# %%time
# used the 3200 candidate variable file
data = pd.read_csv('Data/final_candidate_variables.csv', index_col=0)
# Out:
# <decorator-gen-54>:2: DtypeWarning: Columns (3,25) have mixed types.Specify dtype option on import or set low_memory=False.
# CPU times: user 4min 40s, sys: 1min 29s, total: 6min 9s
# Wall time: 6min 22s

# %%
data['date'] = pd.to_datetime(data.date)

# %%
# drop all the columns with KS score less than 0.2
# this was based on previous trial where I used 400 candidate variables
drop_col = ['fulladdress_homephone_count_7',
            'record',
 'homephone_count_3',
 'name_dob_count_0_by_14',
 'homephone_count_7',
 'ssn_dob_count_0_by_14',
 'name_dob_count_7',
 'ssn_count_0_by_14',
 'ssn_firstname_count_0_by_14',
 'ssn_dob_count_7',
 'ssn_count_7',
 'ssn_name_dob_count_0_by_14',
 'ssn_lastname_count_0_by_14',
 'ssn_firstname_count_7',
 'ssn_lastname_count_7',
 'fulladdress_homephone_count_0_by_14',
 'ssn_name_dob_count_7',
 'ssn_name_count_0_by_14',
 'ssn_name_count_7',
 'homephone_unique_count_for_ssn_3',
 'homephone_unique_count_for_name_dob_3',
 'homephone_count_14',
 'name_count_7',
 'name_count_0_by_30',
 'address_count_0',
 'fulladdress_count_0',
 'homephone_unique_count_for_ssn_7',
 'homephone_unique_count_for_name_dob_7',
 'fulladdress_count_1_by_7',
 'address_count_1_by_7',
 'name_count_0_by_14',
 'homephone_count_30',
 'dob_count_30',
 'fulladdress_homephone_count_3',
 'homephone_day_since',
 'homephone_count_1',
 'homephone_unique_count_for_ssn_14',
 'homephone_unique_count_for_name_dob_14',
 'homephone_unique_count_for_ssn_1',
 'homephone_unique_count_for_name_dob_1',
 'dob_count_14',
 'name_dob_unique_count_for_address_30',
 'name_dob_unique_count_for_homephone_30',
 'name_dob_count_3',
 'name_dob_count_0_by_7',
 'ssn_count_3',
 'ssn_firstname_count_3',
 'ssn_dob_count_3',
 'ssn_name_count_3',
 'ssn_lastname_count_3',
 'ssn_unique_count_for_address_30',
 'fulladdress_homephone_count_0_by_7',
 'ssn_name_dob_count_3',
 'ssn_dob_count_0_by_7',
 'ssn_count_0_by_7',
 'ssn_unique_count_for_homephone_30',
 'ssn_lastname_count_0_by_7',
 'ssn_firstname_count_0_by_7',
 'ssn_name_dob_count_0_by_7',
 'ssn_name_count_0_by_7',
 'name_count_3',
 'name_dob_unique_count_for_homephone_14',
 'name_dob_unique_count_for_address_14',
 'ssn_unique_count_for_address_14',
 'ssn_unique_count_for_homephone_14',
 'name_count_0_by_7',
 'name_dob_unique_count_for_homephone_7',
 'name_dob_unique_count_for_address_7',
 'ssn_unique_count_for_homephone_7',
 'ssn_unique_count_for_address_7',
 'dob_count_7',
 'ssn_dob_count_1_by_30',
 'dob_day_since',
 'homephone_unique_count_for_name_dob_30',
 'name_dob_count_1_by_30',
 'homephone_unique_count_for_ssn_30',
 'fulladdress_homephone_count_1_by_30',
 'ssn_count_1_by_30',
 'ssn_name_dob_count_1_by_30',
 'ssn_firstname_count_1_by_30',
 'ssn_lastname_count_1_by_30',
 'name_dob_unique_count_for_homephone_3',
 'ssn_name_count_1_by_30',
 'dob_count_3',
 'fulladdress_homephone_count_1',
 'name_dob_unique_count_for_address_3',
 'ssn_unique_count_for_homephone_3',
 'ssn_unique_count_for_address_3',
 'name_dob_count_1_by_14',
 'fulladdress_homephone_count_1_by_14',
 'ssn_dob_count_1_by_14',
 'ssn_count_1_by_14',
 'homephone_count_0',
 'ssn_firstname_count_1_by_14',
 'ssn_name_dob_count_1_by_14',
 'name_dob_count_1',
 'ssn_count_1',
 'ssn_firstname_count_1',
 'ssn_lastname_count_1_by_14',
 'ssn_name_count_1',
 'ssn_lastname_count_1',
 'ssn_dob_count_1',
 'ssn_name_dob_count_1',
 'ssn_name_count_1_by_14',
 'name_count_1',
 'fulladdress_homephone_count_0_by_3',
 'name_dob_count_0_by_3',
 'ssn_count_0_by_3',
 'ssn_firstname_count_0_by_3',
 'ssn_dob_count_0_by_3',
 'ssn_name_count_0_by_3',
 'ssn_lastname_count_0_by_3',
 'ssn_name_dob_count_0_by_3',
 'dob_count_0_by_7',
 'name_count_0_by_3',
 'name_dob_unique_count_for_address_1',
 'name_dob_unique_count_for_homephone_1',
 'ssn_unique_count_for_homephone_1',
 'ssn_unique_count_for_address_1',
 'name_count_1_by_30',
 'dob_count_1',
 'dob_count_0_by_3',
 'name_count_1_by_14',
 'homephone_count_0_by_3',
 'fulladdress_count_1_by_3',
 'address_count_1_by_3',
 'dob_count_0_by_14',
 'fulladdress_homephone_count_1_by_7',
 'name_dob_count_1_by_7',
 'ssn_dob_count_1_by_7',
 'ssn_count_1_by_7',
 'ssn_lastname_count_1_by_7',
 'ssn_firstname_count_1_by_7',
 'ssn_name_dob_count_1_by_7',
 'ssn_name_count_1_by_7',
 'name_count_1_by_7',
 'homephone_count_0_by_7',
 'dob_count_1_by_14',
 'dob_count_1_by_7',
 'fulladdress_homephone_count_0',
 'dob_count_0_by_30',
 'address_unique_count_for_homephone_30',
 'name_count_0',
 'ssn_count_0',
 'ssn_firstname_count_0',
 'ssn_dob_count_0',
 'name_dob_count_0',
 'ssn_name_count_0',
 'ssn_lastname_count_0',
 'ssn_name_dob_count_0',
 'homephone_count_1_by_7',
 'address_unique_count_for_homephone_14',
 'dob_count_0',
 'address_unique_count_for_homephone_7',
 'dob_count_1_by_30',
 'address_unique_count_for_homephone_3',
 'homephone_count_1_by_3',
 'homephone_count_0_by_14',
 'dob_count_1_by_3',
 'address_unique_count_for_homephone_1',
 'fulladdress_homephone_count_1_by_3',
 'name_dob_count_1_by_3',
 'ssn_count_1_by_3',
 'ssn_dob_count_1_by_3',
 'ssn_firstname_count_1_by_3',
 'ssn_name_count_1_by_3',
 'ssn_lastname_count_1_by_3',
 'ssn_name_dob_count_1_by_3',
 'name_count_1_by_3',
 'dob_homephone',
 'dob',
 'homephone_count_1_by_14',
 'name_fulladdress_count_30',
 'fulladdress_dob_count_30',
 'name_fulladdress_count_0_by_30',
 'name_homephone_count_30',
 'fulladdress_dob_count_0_by_30',
 'dob_homephone_count_30',
 'homephone_name_dob_count_30',
 'ssn_address_count_30',
 'ssn_fulladdress_count_30',
 'ssn_zip5_count_30',
 'homephone_count_0_by_30',
 'ssn_homephone_count_30',
 'name_homephone_count_0_by_30',
 'dob_homephone_count_0_by_30',
 'homephone_name_dob_count_0_by_30',
 'ssn_address_count_0_by_30',
 'ssn_fulladdress_count_0_by_30',
 'ssn_zip5_count_0_by_30',
 'ssn_homephone_count_0_by_30',
 'name_fulladdress_count_1_by_30',
 'fulladdress_dob_count_1_by_30',
 'name_homephone_count_1_by_30',
 'dob_homephone_count_1_by_30',
 'homephone_name_dob_count_1_by_30',
 'ssn_address_count_1_by_30',
 'ssn_fulladdress_count_1_by_30',
 'ssn_zip5_count_1_by_30',
 'ssn_homephone_count_1_by_30',
 'dob_homephone_day_since',
 'homephone_count_1_by_30',
 'fulladdress_dob_day_since',
 'ssn_homephone_day_since',
 'homephone_name_dob_day_since',
 'homephone_unique_count_for_address_7',
 'homephone_unique_count_for_address_30',
 'ssn_address_day_since',
 'name_homephone_day_since',
 'name_fulladdress_day_since',
 'ssn_fulladdress_day_since',
 'ssn_zip5_day_since',
 'homephone',
 'homephone_name_dob',
 'homephone_unique_count_for_address_14',
 'homephone_unique_count_for_address_3',
 'homephone_unique_count_for_address_1',
 'dob_homephone_count_14',
 'fulladdress_dob_count_14',
 'dob_homephone_count_0_by_14',
 'fulladdress_dob_count_0_by_14',
 'name_fulladdress_count_14',
 'ssn_homephone_count_14',
 'ssn_address_count_14',
 'homephone_name_dob_count_14',
 'name_homephone_count_14',
 'name_fulladdress_count_0_by_14',
 'ssn_homephone_count_0_by_14',
 'ssn_address_count_0_by_14',
 'homephone_name_dob_count_0_by_14',
 'dob_homephone_count_1_by_14',
 'name_homephone_count_0_by_14',
 'ssn_zip5_count_14',
 'ssn_fulladdress_count_14',
 'fulladdress_dob_count_1_by_14',
 'name_fulladdress_count_1_by_14',
 'ssn_fulladdress_count_0_by_14',
 'ssn_zip5_count_0_by_14',
 'ssn_homephone_count_1_by_14',
 'ssn_address_count_1_by_14',
 'homephone_name_dob_count_1_by_14',
 'name_homephone_count_1_by_14',
 'ssn_fulladdress_count_1_by_14',
 'ssn_zip5_count_1_by_14',
 'fulladdress_dob_count_7',
 'dob_homephone_count_7',
 'name_fulladdress_count_7',
 'homephone_name_dob_count_7',
 'name_homephone_count_7',
 'ssn_address_count_7',
 'ssn_homephone_count_7',
 'ssn_zip5_count_7',
 'fulladdress_dob_count_0_by_7',
 'ssn_fulladdress_count_7',
 'name_fulladdress_count_0_by_7',
 'dob_homephone_count_0_by_7',
 'homephone_name_dob_count_0_by_7',
 'ssn_address_count_0_by_7',
 'name_homephone_count_0_by_7',
 'ssn_homephone_count_0_by_7',
 'ssn_fulladdress_count_0_by_7',
 'ssn_zip5_count_0_by_7',
 'fulladdress_dob_count_1_by_7',
 'dob_homephone_count_1_by_7',
 'name_fulladdress_count_1_by_7',
 'homephone_name_dob_count_1_by_7',
 'ssn_address_count_1_by_7',
 'name_homephone_count_1_by_7',
 'ssn_homephone_count_1_by_7',
 'ssn_fulladdress_count_1_by_7',
 'ssn_zip5_count_1_by_7',
 'dow_risk',
 'ssn_name_dob',
 'ssn_firstname',
 'ssn_lastname',
 'ssn_address',
 'ssn_zip5',
 'ssn_dob',
 'ssn_homephone',
 'ssn_name',
 'ssn_fulladdress',
 'ssn',
 'name_fulladdress',
 'name_homephone',
 'name_dob',
 'name',
 'firstname',
 'name_fulladdress_count_3',
 'fulladdress_dob_count_3',
 'dob_homephone_count_3',
 'ssn_address_count_3',
 'name_homephone_count_3',
 'homephone_name_dob_count_3',
 'ssn_zip5_count_3',
 'ssn_fulladdress_count_3',
 'ssn_homephone_count_3',
 'name_fulladdress_count_0_by_3',
 'fulladdress_dob_count_0_by_3',
 'fulladdress_homephone',
 'fulladdress_dob',
 'fulladdress',
 'address',
 'ssn_address_count_0_by_3',
 'name_homephone_count_0_by_3',
 'ssn_fulladdress_count_0_by_3',
 'ssn_zip5_count_0_by_3',
 'dob_homephone_count_0_by_3',
 'homephone_name_dob_count_0_by_3',
 'ssn_homephone_count_0_by_3',
 'zip5',
 'dow',
 'name_fulladdress_count_1_by_3',
 'fulladdress_dob_count_1_by_3',
 'lastname',
 'ssn_address_count_1_by_3',
 'dob_homephone_count_1_by_3',
 'homephone_name_dob_count_1_by_3',
 'ssn_fulladdress_count_1_by_3',
 'ssn_zip5_count_1_by_3',
 'name_homephone_count_1_by_3',
 'ssn_homephone_count_1_by_3',
 'dob_homephone_count_1',
 'ssn_zip5_count_1',
 'ssn_address_count_1',
 'name_fulladdress_count_1',
 'ssn_homephone_count_1',
 'name_homephone_count_1',
 'fulladdress_dob_count_1',
 'ssn_fulladdress_count_1',
 'homephone_name_dob_count_1',
 'name_dob_unique_count_for_ssn_30',
 'name_dob_unique_count_for_ssn_14',
 'dob_homephone_count_0',
 'name_dob_unique_count_for_ssn_7',
 'ssn_address_count_0',
 'ssn_zip5_count_0',
 'name_fulladdress_count_0',
 'homephone_name_dob_count_0',
 'fulladdress_dob_count_0',
 'ssn_homephone_count_0',
 'name_homephone_count_0',
 'ssn_fulladdress_count_0',
 'ssn_unique_count_for_name_dob_30',
 'ssn_unique_count_for_name_dob_14',
 'name_dob_unique_count_for_ssn_3',
 'ssn_unique_count_for_name_dob_7',
 'ssn_unique_count_for_name_dob_3',
 'name_dob_unique_count_for_ssn_1',
 'ssn_unique_count_for_name_dob_1']

# %%
df = data.drop(columns=drop_col).copy()

# %%
# %%time
# create oot train_test data
train_test = df[(df.date > '2016-01-14')&(df.date < '2016-11-01')]
# Out:
# CPU times: user 7.75 s, sys: 15.9 s, total: 23.6 s
# Wall time: 25.3 s

# %%
# create the output dataframe
KSFDR = pd.DataFrame(df.columns, columns=['Variable'])

KSFDR.reset_index(inplace=True)
KSFDR.rename(columns={"index":"Variable Number"}, inplace=True)

# %%
# separate the good and bad
goods = train_test[train_test.fraud_label == 0].copy()
bads = train_test[train_test.fraud_label == 1].copy()

# %%
# %%time
# calculate the KS score
KSFDR['ks'] = np.NaN
cols = train_test.columns

i = 0
for column in cols:
    KSFDR.loc[i,'ks'] = sps.ks_2samp(goods[column],bads[column])[0]
    i = i+1
# Out:
# CPU times: user 2min 30s, sys: 15.7 s, total: 2min 46s
# Wall time: 2min 52s

# %%
KSFDR['rank_ks'] = KSFDR['ks'].rank(ascending = True)
KSFDR.sort_values(by=['rank_ks'], ascending=False, inplace=True)
KSFDR.reset_index(drop=True, inplace=True)

# %%
KSFDR.head(20)
# Out:
#     Variable Number                                           Variable  \
# 0                 1                                        fraud_label
# 1                 5                                  address_day_since
# 2                14                              fulladdress_day_since
# 3                10                                   address_count_30
# 4                19                               fulladdress_count_30
# 5                 9                                   address_count_14
# 6                18                               fulladdress_count_14
# 7                 8                                    address_count_7
# 8                17                                fulladdress_count_7
# 9               214         address_unique_count_for_name_homephone_60
# 10               45                              address_count_0_by_30
# 11              238     address_unique_count_for_homephone_name_dob_60
# ...

# %%
# %%time
# calculate FDR @3%
KSFDR['FDR'] = np.NaN
listvars = list(KSFDR["Variable"])
listvars = listvars[1:]

j = 1
topRows = int(round(len(train_test)*0.03))
numbads = len(train_test[train_test.fraud_label==1])

for column in listvars:
    temp = train_test[[column,'fraud_label']].copy() 
    temp0 = temp.sort_values(column,ascending=False)
    temp1 = temp0.head(topRows)
    temp2 = temp0.tail(topRows)
    needed1 = temp1.loc[:,'fraud_label']
    needed2 = temp2.loc[:,'fraud_label']
    FDR1 = sum(needed1)/numbads
    FDR2 = sum(needed2)/numbads
    FDRate = np.maximum(FDR1,FDR2)
    KSFDR.loc[j, 'FDR'] = FDRate
    j = j + 1
# Out:
# CPU times: user 1min 55s, sys: 29.4 s, total: 2min 25s
# Wall time: 2min 28s

# %%
# fraud_label itself is always 1
KSFDR.loc[0, 'FDR'] = 1

# create FDR rank
KSFDR['rank_FDR'] = KSFDR['FDR'].rank(ascending = True)

# %%
# create average rank
KSFDR['average_rank'] = (KSFDR['rank_ks'] + KSFDR['rank_FDR']) / 2
KSFDR.sort_values(by=['average_rank'], ascending=False, inplace=True)
KSFDR.reset_index(drop=True, inplace=True)

# %%
KSFDR.to_excel('2700_var_full_ksfdr.xlsx')

# %%
# how many variables have KS score greater than 0.25
KSFDR[KSFDR.ks >= 0.25].shape[0]
# Out:
# 197

# %%
# how many variables have FDR score greater than 0.25
KSFDR[KSFDR.FDR >= 0.25].shape[0]
# Out:
# 253

# %%
# Cutoff values at 80th variable based on average_rank
KSFDR.head(80)
# Out:
#     Variable Number                                     Variable        ks  \
# 0                 1                                  fraud_label  1.000000
# 1                 5                            address_day_since  0.334096
# 2                14                        fulladdress_day_since  0.333210
# 3                10                             address_count_30  0.332725
# 4                19                         fulladdress_count_30  0.332032
# ..              ...                                          ...       ...
# 75              219  address_unique_count_for_fulladdress_dob_30  0.279660
# 76              756      fulladdress_unique_count_for_ssn_dob_30  0.280899
# 77                7                              address_count_3  0.278445
# 78              690     fulladdress_unique_count_for_name_dob_30  0.278808
# 79               16                          fulladdress_count_3  0.278488
#
#     rank_ks       FDR  rank_FDR  average_rank
# ...
